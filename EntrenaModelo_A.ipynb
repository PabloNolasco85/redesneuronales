# %% [markdown]
# <img width="800px" src="https://static.wikia.nocookie.net/logopedia/images/5/50/Universidad_Ricardo_Palma.jpg/revision/latest?cb=20210407204705&path-prefix=es"></img>
# # <font color='Darkorange'>Unidad de Posgrado - Maestría en Ciencia de los Datos</font></span>
# ## <font color='Steelblue'> PROYECTO DE APLICACIÓN – REDES NEURONALES</font></span>
# ## Alumnos:
# Pablo Nolasco Huaraca \
# Jonathan De la Torre Eguren \
# Henry Parrales Bringas \
# Juan Ricciotti Giribaldi Rocha \

# %% [markdown]
# 2. ⚙️ **Configurar entorno YOLOv8 en Colab**

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 54.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 126.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 100.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 101.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# 3. 🔗 **Montar Google Drive y navegar a tu dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset_path ='/content/drive/MyDrive/CONTENIDO_PROYECTO_REDES/data.yaml'

# %% [markdown]
# 4. 🧠 **Entrenar el modelo YOLOv8**

# %%
# Cargar modelo base (puedes usar yolov8n.pt, yolov8s.pt, etc.)
model = YOLO("yolov8n.pt")
# Entrenar
model.train(data=dataset_path, epochs=50, imgsz=640,patience=10)
# Out:
# Ultralytics 8.3.168 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# 🗂 **GUARDAR EL MODELO**

# %%
# !cp -r /content/runs/detect/train /content/drive/MyDrive/CONTENIDO_PROYECTO_REDES/MODELO_A/

# %% [markdown]
# 6. 🔍 **Usar Modelo**

# %%
# Cargar mejor modelo
model = YOLO("runs/detect/train/weights/best.pt")

# Ejecutar detección sobre una imagen
results = model("/content/drive/MyDrive/CONTENIDO_PROYECTO_REDES/IMAGENES_TEST/videos.mp4")

# Mostrar resultados
results[0].show()

# %% [markdown]
# 🗂 **USO MODELO GUARDADO**

# %%
from ultralytics import YOLO

# Cargar el modelo ya entrenado
model = YOLO("/content/drive/MyDrive/CONTENIDO_PROYECTO_REDES/MODELO_A/train/weights/best.pt")

results = model("/content/drive/MyDrive/CONTENIDO_PROYECTO_REDES/IMAGENES_TEST/imagen7.jpg")
results[0].show()
# Out:
# image 1/1 /content/drive/MyDrive/CONTENIDO_PROYECTO_REDES/IMAGENES_TEST/imagen7.jpg: 640x480 1 persona_agresora, 1 persona_normal, 9.5ms
# Speed: 2.3ms preprocess, 9.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
# <PIL.Image.Image image mode=RGB size=334x451>

# %%
from ultralytics import YOLO

# Cargar el modelo ya entrenado
model = YOLO("/content/drive/MyDrive/CONTENIDO_PROYECTO_REDES/MODELO_A/train/weights/best.pt")

results = model("/content/drive/MyDrive/CONTENIDO_PROYECTO_REDES/IMAGENES_TEST/imagen13.jpg")
results[0].show()
# Out:
# image 1/1 /content/drive/MyDrive/CONTENIDO_PROYECTO_REDES/IMAGENES_TEST/imagen13.jpg: 448x640 1 persona_normal, 9.2ms
# Speed: 2.5ms preprocess, 9.2ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=450x300>

# %%
from ultralytics import YOLO

# Cargar el modelo ya entrenado
model = YOLO("/content/drive/MyDrive/CONTENIDO_PROYECTO_REDES/MODELO_A/train/weights/best.pt")

results = model("/content/drive/MyDrive/CONTENIDO_PROYECTO_REDES/IMAGENES_TEST/imagen14.jpg")
results[0].show()
# Out:
# image 1/1 /content/drive/MyDrive/CONTENIDO_PROYECTO_REDES/IMAGENES_TEST/imagen14.jpg: 608x640 2 persona_normals, 9.5ms
# Speed: 2.8ms preprocess, 9.5ms inference, 1.6ms postprocess per image at shape (1, 3, 608, 640)
# <PIL.Image.Image image mode=RGB size=390x370>

# %%
from ultralytics import YOLO

# Cargar el modelo ya entrenado
model = YOLO("/content/drive/MyDrive/CONTENIDO_PROYECTO_REDES/MODELO_A/train/weights/best.pt")

results = model("/content/drive/MyDrive/CONTENIDO_PROYECTO_REDES/IMAGENES_TEST/imagen23.jpg")
results[0].show()
# Out:
# image 1/1 /content/drive/MyDrive/CONTENIDO_PROYECTO_REDES/IMAGENES_TEST/imagen23.jpg: 640x640 2 vandalismos, 8.1ms
# Speed: 2.2ms preprocess, 8.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>
